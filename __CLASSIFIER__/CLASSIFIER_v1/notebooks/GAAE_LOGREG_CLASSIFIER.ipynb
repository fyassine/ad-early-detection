# %% [markdown]
# # [v2] Static per-scan classification — GAAE + LogReg
#
# **Task: static single-scan classification.** Each scan is one sample;
# labels are the subject's eventual converter status. This is *not* longitudinal
# and *not* early-detection — it tests whether a single scan's GAAE embedding
# is predictive on its own.
#
# v2 adds **subject-level rollup** of the scan-level AUC at the end of the
# notebook. Quote both numbers in any final table.

# %% [markdown]
# # GAAE Latent Space → Logistic Regression Classifier
#
# Encoder-frozen GAAE → mean-pool graph embeddings → logistic regression head for converter vs stable-MCI classification.
#
# Follows the same 5-fold stratified subject-level CV structure as the Cost-Weighted GEC notebook.

# %%
import sys
from pathlib import Path
model_root = Path('/mnt/e/fyassine/ad-early-detection/CLASSIFIER')
if str(model_root) not in sys.path:
    sys.path.insert(0, str(model_root))

# %%
import json, os, warnings
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.metrics import (
    roc_auc_score, roc_curve, confusion_matrix,
    f1_score, classification_report
)
from torch_geometric.loader import DataLoader
from torch_geometric.utils import unbatch
from model.GAAE.models import GraphAttentionAutoencoderConditioned
from model.GAAE.dataset import GraphDatasetInMemoryFiltered
from model.GAAE.utils import knn_binary_adjacency_matrix_no_diag
warnings.filterwarnings('ignore')
print('Imports OK')
# Out:
# Imports OK

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')
# Out:
# Device: cuda

# %% [markdown]
# ## Configuration

# %%
def set_seed(seed):
    import random
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

RANDOM_STATE = 42
set_seed(RANDOM_STATE)

# ── Paths ────────────────────────────────────────────────────────────────
WB_DATA_ROOT  = '/mnt/e/fyassine/ad-early-detection/DATA/DELCODE/__v3__/matrices'
METADATA_DIR  = '/mnt/e/fyassine/ad-early-detection/DATA/DELCODE/__v3__/metadata'
SPLITS_DIR    = os.path.join(METADATA_DIR, 'splits_gaae')
TRAIN_CSV     = os.path.join(SPLITS_DIR, 'train.csv')
VAL_CSV       = os.path.join(SPLITS_DIR, 'val.csv')
TEST_CSV      = os.path.join(SPLITS_DIR, 'test.csv')
ALL_INFO_CSV  = os.path.join(SPLITS_DIR, '_all_splits_patient_info.csv')

CHECKPOINT_SEARCH_DIRS = [
    str(model_root / 'notebooks' / 'checkpoints_gaae_whole_brain'),
    str(model_root / 'notebooks' / 'checkpoints_gaae_dmn'),
]
OUTPUT_DIR = str(model_root / 'notebooks' / 'checkpoints_gaae_logreg')
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ── GAAE hyper-params (must match checkpoint) ─────────────────────────
CONFIG_PATH = model_root / 'configs' / 'gaae_delcode_whole_brain.json'

# ── Encoding ──────────────────────────────────────────────────────────
GRAPH_POOL = 'mean'   # 'mean' | 'max' | 'sum'

# ── Logistic regression ───────────────────────────────────────────────
LR_C            = 1.0      # inverse regularisation strength
LR_MAX_ITER     = 2000
LR_CLASS_WEIGHT = 'balanced'

# ── CV ────────────────────────────────────────────────────────────────
N_FOLDS = 5

# Use an existing run dir instead of retraining?
USE_EXISTING_CHECKPOINT = False

print('Config set.')
# Out:
# Config set.

# %%
# v2 split-hygiene audit — hard-fails if any subject crosses splits.
import sys
from pathlib import Path
_V2_ROOT = Path('/mnt/e/fyassine/ad-early-detection/CLASSIFIER')
if str(_V2_ROOT) not in sys.path:
    sys.path.insert(0, str(_V2_ROOT))
from common.sanity import run_full_audit
if 'METADATA_DIR' in globals():
    _splits_dir = Path(METADATA_DIR) / 'splits_gaae'
    _ = run_full_audit({
        'train': str(_splits_dir / 'train.csv'),
        'val':   str(_splits_dir / 'val.csv'),
        'test':  str(_splits_dir / 'test.csv'),
    })
else:
    print('[SANITY] METADATA_DIR not defined in this notebook — skipping split audit')

# %% [markdown]
# ## Select & load GAAE checkpoint

# %%
checkpoint_candidates = sorted(
    [
        (run_dir.name, str(run_dir / f'model_{run_dir.name}.pth'), str(run_dir))
        for ckpt_dir in CHECKPOINT_SEARCH_DIRS
        for base_path in [Path(ckpt_dir)]
        if base_path.is_dir()
        for run_dir in sorted(base_path.iterdir())
        if run_dir.is_dir()
        if (run_dir / f'model_{run_dir.name}.pth').exists()
    ],
    key=lambda x: x[0],
)

if not checkpoint_candidates:
    raise FileNotFoundError('No GAAE checkpoints found.')

print('Available GAAE checkpoints:')
for i, (name, path, rdir) in enumerate(checkpoint_candidates):
    print(f'  {i}: {name}')

selected_idx = int(input('Select checkpoint index: '))
GAAE_RUN_NAME, GAAE_CKPT_PATH, GAAE_RUN_DIR = checkpoint_candidates[selected_idx]
print(f'\nSelected: {GAAE_RUN_NAME}')
# Out:
# Available GAAE checkpoints:
#   0: bright-disco-4_2026-05-07_20-17-11
#   1: dark-blaze-8_2026-03-24_01-53-42
#   2: worldly-plasma-2_2026-03-24_01-00-18
#
# Selected: bright-disco-4_2026-05-07_20-17-11

# %%
if CONFIG_PATH.exists():
    with open(CONFIG_PATH) as f:
        hp = json.load(f)
    print('Loaded config from', CONFIG_PATH)
else:
    hp = dict(latent_dim=64, num_heads=2, cond_dim=2, dropout=0.3,
              adjacency_k=8, file_variant='z_transformed')
    print('Config not found – using defaults.')

adjacency_args = {'k': hp.get('adjacency_k', 8)}
file_variant   = hp.get('file_variant', 'z_transformed')
OUT_FEATURES   = hp.get('latent_dim', 64)
NUM_HEADS      = hp.get('num_heads', 2)
COND_DIM       = hp.get('cond_dim', 2)
DROPOUT        = hp.get('dropout', 0.3)

# probe in_features via one sample
_probe = GraphDatasetInMemoryFiltered(
    root=WB_DATA_ROOT,
    adjacency_function=knn_binary_adjacency_matrix_no_diag,
    adjacency_args=adjacency_args,
    filter_csv_path=TEST_CSV,
    file_variant=file_variant,
)
IN_FEATURES = _probe[0].x.size(1)
print(f'IN_FEATURES={IN_FEATURES}  LATENT_DIM={OUT_FEATURES}')

gaae_model = GraphAttentionAutoencoderConditioned(
    in_features=IN_FEATURES, hidden_dim=IN_FEATURES,
    out_features=OUT_FEATURES, cond_dim=COND_DIM,
    num_heads=NUM_HEADS, dropout=DROPOUT,
).to(device)

ckpt_obj = torch.load(GAAE_CKPT_PATH, map_location=device)
if isinstance(ckpt_obj, dict):
    gaae_model.load_state_dict(ckpt_obj)
else:
    gaae_model = ckpt_obj.to(device)
gaae_model.eval()
for p in gaae_model.parameters():
    p.requires_grad_(False)
print('GAAE encoder loaded and frozen.')
# Out:
# Loaded config from /mnt/e/fyassine/ad-early-detection/CLASSIFIER/configs/gaae_delcode_whole_brain.json
# IN_FEATURES=200  LATENT_DIM=64
# GAAE encoder loaded and frozen.

# %% [markdown]
# ## Load datasets
#
# Merge train+val split CSVs, filter to MCI+converter subjects, build one combined dataset.

# %%
import tempfile

train_df = pd.read_csv(TRAIN_CSV)
val_df   = pd.read_csv(VAL_CSV)
test_df  = pd.read_csv(TEST_CSV)

# Build merged patient-info CSV (sex/age) once
if not os.path.exists(ALL_INFO_CSV):
    _info = pd.concat(
        [df[['Repseudonym','sex','age']] for df in [train_df, val_df, test_df]],
        ignore_index=True,
    ).drop_duplicates('Repseudonym').reset_index(drop=True)
    _info.to_csv(ALL_INFO_CSV, index=False)
    print(f'Wrote {ALL_INFO_CSV}')

# CV pool = train + val (test held out)
cv_pool_df = pd.concat([train_df, val_df], ignore_index=True)
mci_pool   = cv_pool_df[cv_pool_df['diagnosis'].isin(['mci', 'converter'])].copy()
test_mci   = test_df[test_df['diagnosis'].isin(['mci', 'converter'])].copy()

print('CV pool diagnoses:', mci_pool['diagnosis'].value_counts().to_dict())
print('Test  diagnoses:  ', test_mci['diagnosis'].value_counts().to_dict())

def make_dataset(subset_df, label='subset'):
    tmp = tempfile.NamedTemporaryFile(suffix='.csv', delete=False, mode='w')
    subset_df.to_csv(tmp.name, index=False)
    tmp.close()
    ds = GraphDatasetInMemoryFiltered(
        root=WB_DATA_ROOT,
        adjacency_function=knn_binary_adjacency_matrix_no_diag,
        adjacency_args=adjacency_args,
        filter_csv_path=tmp.name,
        patient_info_path=ALL_INFO_CSV,
        separator=',',
        file_variant=file_variant,
    )
    print(f'{label}: {len(ds)} scans from {subset_df["Repseudonym"].nunique()} subjects')
    return ds

cv_dataset   = make_dataset(mci_pool, 'CV pool')
test_dataset = make_dataset(test_mci,  'Test')
# Out:
# CV pool diagnoses: {'mci': 89, 'converter': 52}
# Test  diagnoses:   {'mci': 10, 'converter': 6}
# Processing...
# Done!
# CV pool: 422 scans from 141 subjects
# Processing...
# Test: 48 scans from 16 subjects
# Done!

# %% [markdown]
# ## Embedding extraction

# %%
def extract_embeddings(dataset, batch_size=32):
    """Encode all samples → (N, F) numpy array + patient-id list."""
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    all_emb, all_pids = [], []
    gaae_model.eval()
    with torch.no_grad():
        for batch in loader:
            batch = batch.to(device)
            z = gaae_model.encode(batch.x, batch.edge_index, batch.edge_attr)  # (N_nodes, F)
            z_list = unbatch(z, batch.batch)
            for z_g in z_list:
                if GRAPH_POOL == 'mean':
                    emb = z_g.mean(0)
                elif GRAPH_POOL == 'max':
                    emb = z_g.max(0).values
                else:
                    emb = z_g.sum(0)
                all_emb.append(emb.cpu().numpy())
            pids = batch.patient_id if isinstance(batch.patient_id, list) else [batch.patient_id]
            all_pids.extend([str(p).split('_')[0] for p in pids])
    return np.stack(all_emb), all_pids

cv_emb, cv_pids  = extract_embeddings(cv_dataset)
te_emb, te_pids  = extract_embeddings(test_dataset)

# Build labels (1=converter, 0=stable-mci)
id2diag = dict(zip(mci_pool['Repseudonym'].astype(str), mci_pool['diagnosis']))
id2diag.update(dict(zip(test_mci['Repseudonym'].astype(str), test_mci['diagnosis'])))

cv_labels  = np.array([1 if id2diag.get(p,'mci')=='converter' else 0 for p in cv_pids])
te_labels  = np.array([1 if id2diag.get(p,'mci')=='converter' else 0 for p in te_pids])
cv_groups  = np.array(cv_pids)   # one group per subject → no leakage

print(f'CV:   {cv_emb.shape}  converter={cv_labels.sum()}  mci={(1-cv_labels).sum()}')
print(f'Test: {te_emb.shape}  converter={te_labels.sum()}  mci={(1-te_labels).sum()}')
# Out:
# CV:   (422, 64)  converter=177  mci=245
# Test: (48, 64)  converter=19  mci=29

# %% [markdown]
# ## 5-Fold Stratified Subject-Level Cross-Validation
#
# Each fold trains a `StandardScaler + LogisticRegression` on the GAAE embeddings.
# Groups ensure a subject's scans never split across train/val.

# %%
cv_results = {
    'fold': [], 'val_auc': [], 'val_sensitivity': [],
    'val_specificity': [], 'val_f1': [], 'best_threshold': [],
}
oof_preds   = []
oof_targets = []
oof_indices = []

best_val_auc       = 0.0
best_fold          = -1
best_scaler        = None
best_clf           = None
best_threshold_overall = 0.5
best_f1_threshold      = 0.5

sgkf = StratifiedGroupKFold(n_splits=N_FOLDS)

for fold, (tr_idx, va_idx) in enumerate(sgkf.split(cv_emb, cv_labels, groups=cv_groups)):
    X_tr, y_tr = cv_emb[tr_idx], cv_labels[tr_idx]
    X_va, y_va = cv_emb[va_idx], cv_labels[va_idx]

    sc  = StandardScaler().fit(X_tr)
    clf = LogisticRegression(C=LR_C, max_iter=LR_MAX_ITER,
                             class_weight=LR_CLASS_WEIGHT,
                             random_state=RANDOM_STATE)
    clf.fit(sc.transform(X_tr), y_tr)

    prob = clf.predict_proba(sc.transform(X_va))[:, 1]
    oof_preds.extend(prob.tolist())
    oof_targets.extend(y_va.tolist())
    oof_indices.extend(va_idx.tolist())

    auc = roc_auc_score(y_va, prob)

    # Youden threshold
    fpr_, tpr_, thr_ = roc_curve(y_va, prob)
    j = tpr_ - fpr_
    best_thr = float(thr_[np.argmax(j)])

    pred = (prob >= best_thr).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_va, pred).ravel() if len(np.unique(y_va)) > 1 else (0,0,0,0)
    sens = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    spec = tn / (tn + fp) if (tn + fp) > 0 else 0.0
    f1   = f1_score(y_va, pred, zero_division=0)

    cv_results['fold'].append(fold + 1)
    cv_results['val_auc'].append(auc)
    cv_results['val_sensitivity'].append(sens)
    cv_results['val_specificity'].append(spec)
    cv_results['val_f1'].append(f1)
    cv_results['best_threshold'].append(best_thr)

    print(f'Fold {fold+1}: AUC={auc:.3f}  sens={sens:.3f}  spec={spec:.3f}  F1={f1:.3f}  thr={best_thr:.3f}')

    if auc > best_val_auc:
        best_val_auc = auc
        best_fold    = fold + 1
        best_scaler  = sc
        best_clf     = clf
        best_threshold_overall = best_thr

# OOF F1-optimal threshold
oof_arr = np.array(oof_preds)
oof_tgt = np.array(oof_targets)
_, _, thrs = roc_curve(oof_tgt, oof_arr)
f1s = [f1_score(oof_tgt, (oof_arr >= t).astype(int), zero_division=0) for t in thrs]
best_f1_threshold = float(thrs[np.argmax(f1s)])

print(f'\nBest fold: {best_fold}  AUC={best_val_auc:.4f}')
print(f'Youden threshold: {best_threshold_overall:.4f}')
print(f'F1-optimal OOF threshold: {best_f1_threshold:.4f}')
# Out:
# Fold 1: AUC=0.749  sens=0.857  spec=0.510  F1=0.674  thr=0.347
# Fold 2: AUC=0.828  sens=0.889  spec=0.755  F1=0.800  thr=0.421
# Fold 3: AUC=0.798  sens=0.750  spec=0.755  F1=0.720  thr=0.624
# Fold 4: AUC=0.799  sens=0.943  spec=0.551  F1=0.733  thr=0.155
# Fold 5: AUC=0.700  sens=0.857  spec=0.612  F1=0.714  thr=0.311
#
# Best fold: 2  AUC=0.8277
# Youden threshold: 0.4206
# F1-optimal OOF threshold: 0.1937

# %% [markdown]
# ## Cross-Validation Results Summary

# %%
print('\nCross-Validation Summary:')
print('=' * 60)
print(f"{'Metric':<20} {'Mean':>10} {'Std':>10} {'Min':>10} {'Max':>10}")
print('-' * 60)
for metric in ['val_auc', 'val_sensitivity', 'val_specificity', 'val_f1']:
    v = cv_results[metric]
    print(f'{metric:<20} {np.mean(v):>10.4f} {np.std(v):>10.4f} {np.min(v):>10.4f} {np.max(v):>10.4f}')
print(f'\nBest fold: {best_fold}  AUC={best_val_auc:.4f}')
print(f'Youden thr: {best_threshold_overall:.4f}   F1-OOF thr: {best_f1_threshold:.4f}')
# Out:
# Cross-Validation Summary:
# ============================================================
# Metric                     Mean        Std        Min        Max
# ------------------------------------------------------------
# val_auc                  0.7747     0.0452     0.6997     0.8277
# val_sensitivity          0.8592     0.0629     0.7500     0.9429
# val_specificity          0.6367     0.1020     0.5102     0.7551
# val_f1                   0.7284     0.0409     0.6742     0.8000
#
# Best fold: 2  AUC=0.8277
# Youden thr: 0.4206   F1-OOF thr: 0.1937

# %%
def _oof_metrics(thr):
    p = (oof_arr >= thr).astype(int)
    tn, fp, fn, tp = confusion_matrix(oof_tgt, p).ravel() if len(np.unique(oof_tgt))>1 else (0,0,0,0)
    sens = tp/(tp+fn) if (tp+fn)>0 else 0.0
    spec = tn/(tn+fp) if (tn+fp)>0 else 0.0
    f1   = f1_score(oof_tgt, p, zero_division=0)
    return sens, spec, f1

y_s, y_sp, y_f1 = _oof_metrics(best_threshold_overall)
f_s, f_sp, f_f1 = _oof_metrics(best_f1_threshold)
print('OOF threshold options:')
print(f"  [1] Youden   thr={best_threshold_overall:.4f}  sens={y_s:.3f}  spec={y_sp:.3f}  F1={y_f1:.3f}")
print(f"  [2] Best-F1  thr={best_f1_threshold:.4f}  sens={f_s:.3f}  spec={f_sp:.3f}  F1={f_f1:.3f}")

choice = input('Select threshold [1=Youden (default), 2=Best-F1]: ').strip()
if choice == '2':
    ACTIVE_THRESHOLD = best_f1_threshold
    THRESHOLD_METHOD = 'oof_f1'
else:
    ACTIVE_THRESHOLD = best_threshold_overall
    THRESHOLD_METHOD = 'oof_youden'
print(f'Using {THRESHOLD_METHOD} threshold: {ACTIVE_THRESHOLD:.4f}')
# Out:
# OOF threshold options:
#   [1] Youden   thr=0.4206  sens=0.814  spec=0.637  F1=0.702
#   [2] Best-F1  thr=0.1937  sens=0.927  spec=0.518  F1=0.715
# Using oof_f1 threshold: 0.1937

# %% [markdown]
# ## Save best model

# %%
import pickle
from datetime import datetime

run_timestamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
run_name      = f'gaae_logreg_{run_timestamp}'
run_dir       = Path(OUTPUT_DIR) / run_name
run_dir.mkdir(parents=True, exist_ok=True)

with open(run_dir / 'scaler.pkl', 'wb') as f:
    pickle.dump(best_scaler, f)
with open(run_dir / 'classifier.pkl', 'wb') as f:
    pickle.dump(best_clf, f)

run_summary = {
    'run_name': run_name,
    'gaae_checkpoint': GAAE_RUN_NAME,
    'gaae_ckpt_path': GAAE_CKPT_PATH,
    'graph_pool': GRAPH_POOL,
    'n_folds': N_FOLDS,
    'best_fold': int(best_fold),
    'best_val_auc': float(best_val_auc),
    'active_threshold': float(ACTIVE_THRESHOLD),
    'threshold_method': THRESHOLD_METHOD,
    'youden_threshold': float(best_threshold_overall),
    'f1_threshold': float(best_f1_threshold),
    'cv_results': cv_results,
    'lr_C': LR_C,
    'lr_class_weight': str(LR_CLASS_WEIGHT),
    # ── test metrics populated by test-eval cell below ──
    'test_auc': None,
    'test_sensitivity': None,
    'test_specificity': None,
    'test_f1': None,
}
with open(run_dir / 'run_summary.json', 'w') as f:
    json.dump(run_summary, f, indent=2)
print(f'Saved to {run_dir}')
LOGREG_RUN_DIR = run_dir   # used by test-eval to back-patch test metrics
# Out:
# Saved to /mnt/e/fyassine/ad-early-detection/CLASSIFIER/notebooks/checkpoints_gaae_logreg/gaae_logreg_2026-05-08_10-44-28

# %% [markdown]
# ## Test-Set Evaluation
#
# Evaluate the best scaler+classifier on the held-out test set.

# %%
X_te_scaled = best_scaler.transform(te_emb)
te_prob      = best_clf.predict_proba(X_te_scaled)[:, 1]
te_pred      = (te_prob >= ACTIVE_THRESHOLD).astype(int)

te_auc  = roc_auc_score(te_labels, te_prob) if len(np.unique(te_labels)) > 1 else 0.0
cm_te   = confusion_matrix(te_labels, te_pred, labels=[0, 1])
tn,fp,fn,tp = cm_te.ravel() if cm_te.size == 4 else (0,0,0,0)
te_sens = tp / (tp + fn + 1e-9)
te_spec = tn / (tn + fp + 1e-9)
te_f1   = f1_score(te_labels, te_pred, zero_division=0)

print(f'Test AUC={te_auc:.4f}  Sens={te_sens:.4f}  Spec={te_spec:.4f}  F1={te_f1:.4f}')
print()
print(classification_report(te_labels, te_pred, target_names=['stable_mci', 'converter']))

# Back-patch run_summary.json with test metrics
summary_path = LOGREG_RUN_DIR / 'run_summary.json'
with open(summary_path) as _f:
    _summary = json.load(_f)
_summary.update({
    'test_auc':           float(te_auc),
    'test_sensitivity':   float(te_sens),
    'test_specificity':   float(te_spec),
    'test_f1':            float(te_f1),
    'test_probabilities': te_prob.tolist(),
    'test_labels':        te_labels.tolist(),
})
with open(summary_path, 'w') as _f:
    json.dump(_summary, _f, indent=2)
print(f'Test metrics saved to {summary_path}')
# Out:
# Test AUC=0.7967  Sens=0.7895  Spec=0.5517  F1=0.6383
#
#               precision    recall  f1-score   support
#
#   stable_mci       0.80      0.55      0.65        29
#    converter       0.54      0.79      0.64        19
#
#     accuracy                           0.65        48
#    macro avg       0.67      0.67      0.65        48
# weighted avg       0.70      0.65      0.65        48
#
# Test metrics saved to /mnt/e/fyassine/ad-early-detection/CLASSIFIER/notebooks/checkpoints_gaae_logreg/gaae_logreg_2026-05-08_10-44-28/run_summary.json

# %% [markdown]
# ## ROC Curves

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 5))

# Left: per-fold + OOF
ax = axes[0]
sgkf2 = StratifiedGroupKFold(n_splits=N_FOLDS)
for fold, (tr_i, va_i) in enumerate(sgkf2.split(cv_emb, cv_labels, groups=cv_groups)):
    sc2  = StandardScaler().fit(cv_emb[tr_i])
    clf2 = LogisticRegression(C=LR_C, max_iter=LR_MAX_ITER,
                              class_weight=LR_CLASS_WEIGHT, random_state=RANDOM_STATE)
    clf2.fit(sc2.transform(cv_emb[tr_i]), cv_labels[tr_i])
    p2   = clf2.predict_proba(sc2.transform(cv_emb[va_i]))[:, 1]
    fpr2, tpr2, _ = roc_curve(cv_labels[va_i], p2)
    auc2 = roc_auc_score(cv_labels[va_i], p2)
    ax.plot(fpr2, tpr2, alpha=0.5, lw=1, label=f'Fold {fold+1} ({auc2:.3f})')

oof_fpr, oof_tpr, _ = roc_curve(oof_tgt, oof_arr)
oof_auc = roc_auc_score(oof_tgt, oof_arr)
ax.plot(oof_fpr, oof_tpr, 'k-', lw=2, label=f'OOF ({oof_auc:.3f})')
ax.plot([0,1],[0,1],'--',color='gray',lw=1)
ax.set_xlabel('FPR'); ax.set_ylabel('TPR')
ax.set_title('CV Fold ROC curves')
ax.legend(fontsize=8); ax.grid(alpha=0.3)

# Right: test set
ax2 = axes[1]
te_fpr, te_tpr, _ = roc_curve(te_labels, te_prob)
ax2.plot(te_fpr, te_tpr, 'r-', lw=2, label=f'Test AUC={te_auc:.3f}')
ax2.axvline(1-te_spec, color='blue', linestyle=':', lw=1.5, label=f'Threshold={ACTIVE_THRESHOLD:.3f}')
ax2.plot([0,1],[0,1],'--',color='gray',lw=1)
ax2.set_xlabel('FPR'); ax2.set_ylabel('TPR')
ax2.set_title('Test-Set ROC')
ax2.legend(fontsize=9); ax2.grid(alpha=0.3)

fig.suptitle(f'GAAE LogReg  |  GAAE: {GAAE_RUN_NAME}', fontsize=11)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Robustness Evaluation
#
# Tests the classifier stability under input perturbations (feature noise, edge perturbation, conditioning noise).

# %%
noise_methods = ['none', 'feature_noise', 'edge_perturbation', 'conditioning_noise']
noise_levels  = [0.0, 0.05, 0.10, 0.20, 0.30]
n_trials      = 5

def perturb_and_embed(sample, method, noise_level):
    """Perturb one graph sample and return its embedding."""
    d = sample.clone()
    if noise_level == 0.0 or method == 'none':
        pass
    elif method == 'feature_noise':
        std = float(d.x.std().item()) if d.x.numel() > 1 else 1.0
        d.x = d.x + torch.randn_like(d.x) * (std * noise_level)
    elif method == 'edge_perturbation':
        n_edges = d.edge_index.size(1)
        n_drop  = max(1, int(n_edges * noise_level))
        keep    = torch.randperm(n_edges)[n_drop:]
        d.edge_index = d.edge_index[:, keep]
        if d.edge_attr is not None:
            d.edge_attr = d.edge_attr[keep]
    elif method == 'conditioning_noise':
        std = float(d.x.std().item()) if d.x.numel() > 1 else 1.0
        d.x = d.x + torch.randn_like(d.x) * (std * noise_level * 0.5)

    d = d.to(device)
    with torch.no_grad():
        z = gaae_model.encode(d.x.unsqueeze(0) if d.x.dim()==1 else d.x,
                              d.edge_index, d.edge_attr)
        emb = (z.mean(0) if GRAPH_POOL=='mean' else
               z.max(0).values if GRAPH_POOL=='max' else z.sum(0))
    return emb.cpu().numpy()

# baseline: encode all CV samples without noise
baseline_records = []
for i in range(len(cv_dataset)):
    emb = perturb_and_embed(cv_dataset[i], 'none', 0.0)
    prob_b = best_clf.predict_proba(best_scaler.transform(emb[None]))[0,1]
    pred_b = int(prob_b >= ACTIVE_THRESHOLD)
    pid    = str(getattr(cv_dataset[i], 'patient_id', i))
    baseline_records.append({'DatasetIndex': i, 'PatientID': pid,
                             'TrueLabel': int(cv_labels[i]),
                             'Probability': float(prob_b),
                             'Predicted': pred_b,
                             'AbsMargin': abs(prob_b - ACTIVE_THRESHOLD)})
baseline_df = pd.DataFrame(baseline_records)
print(f'Baseline CV accuracy: {(baseline_df["Predicted"]==baseline_df["TrueLabel"]).mean():.3f}')
# Out:
# Baseline CV accuracy: 0.713

# %%
# Robustness: per-subject stability across noise methods
rob_records = []
for i in range(len(cv_dataset)):
    sample   = cv_dataset[i]
    true_lbl = int(cv_labels[i])
    pid      = str(getattr(sample, 'patient_id', i))
    for method in noise_methods:
        for nl in noise_levels:
            correct_count = 0
            for _ in range(n_trials):
                emb  = perturb_and_embed(sample, method, nl)
                prob = best_clf.predict_proba(best_scaler.transform(emb[None]))[0,1]
                pred = int(prob >= ACTIVE_THRESHOLD)
                correct_count += int(pred == true_lbl)
            rob_records.append({
                'PatientID': pid, 'TrueLabel': true_lbl,
                'Method': method, 'NoiseLevel': nl,
                'StabilityRate': correct_count / n_trials,
            })

rob_df = pd.DataFrame(rob_records)
diag_map = {1: 'converter', 0: 'mci'}
rob_df['SelectionCohort'] = rob_df['TrueLabel'].map(diag_map)

summary = (
    rob_df.groupby(['SelectionCohort','Method','NoiseLevel'])['StabilityRate']
    .mean().reset_index().rename(columns={'StabilityRate':'CohortStabilityRate'})
)
print('Cohort stability summary (higher is better):')
print(summary.to_string(index=False))
# Out:
# Cohort stability summary (higher is better):
# SelectionCohort             Method  NoiseLevel  CohortStabilityRate
#       converter conditioning_noise        0.00             0.971751
#       converter conditioning_noise        0.05             0.968362
#       converter conditioning_noise        0.10             0.969492
#       converter conditioning_noise        0.20             0.968362
#       converter conditioning_noise        0.30             0.969492
#       converter  edge_perturbation        0.00             0.971751
#       converter  edge_perturbation        0.05             0.966102
#       converter  edge_perturbation        0.10             0.962712
#       converter  edge_perturbation        0.20             0.954802
#       converter  edge_perturbation        0.30             0.944633
#       converter      feature_noise        0.00             0.971751
#       converter      feature_noise        0.05             0.969492
#       converter      feature_noise        0.10             0.971751
#       converter      feature_noise        0.20             0.974011
#       converter      feature_noise        0.30             0.976271
#       converter               none        0.00             0.971751
#       converter               none        0.05             0.971751
#       converter               none        0.10             0.971751
#       converter               none        0.20             0.971751
#       converter               none        0.30             0.971751
#             mci conditioning_noise        0.00             0.526531
#             mci conditioning_noise        0.05             0.526531
#             mci conditioning_noise        0.10             0.526531
#             mci conditioning_noise        0.20             0.525714
#             mci conditioning_noise        0.30             0.528163
#             mci  edge_perturbation        0.00             0.526531
#             mci  edge_perturbation        0.05             0.528980
#             mci  edge_perturbation        0.10             0.546122
#             mci  edge_perturbation        0.20             0.563265
#             mci  edge_perturbation        0.30             0.602449
#             mci      feature_noise        0.00             0.526531
#             mci      feature_noise        0.05             0.526531
#             mci      feature_noise        0.10             0.526531
#             mci      feature_noise        0.20             0.524898
#             mci      feature_noise        0.30             0.520816
#             mci               none        0.00             0.526531
#             mci               none        0.05             0.526531
#             mci               none        0.10             0.526531
#             mci               none        0.20             0.526531
#             mci               none        0.30             0.526531

# %% [markdown]
# ## Robustness Plot

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)
palette = {'converter': '#F44336', 'mci': '#2196F3'}

for ax, method in zip(axes, ['feature_noise', 'edge_perturbation']):
    sub = summary[summary['Method'] == method]
    for cohort, grp in sub.groupby('SelectionCohort'):
        ax.plot(grp['NoiseLevel'] * 100, grp['CohortStabilityRate'],
                marker='o', label=cohort, color=palette.get(cohort, 'gray'))
    ax.set_title(method.replace('_', ' ').title())
    ax.set_xlabel('Noise Level (%)')
    ax.set_ylabel('Stability Rate')
    ax.set_ylim(0, 1.05)
    ax.legend(title='Cohort'); ax.grid(alpha=0.3)

fig.suptitle('Robustness: LogReg on GAAE Latent Space', fontsize=12)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Per-Class Robustness
#
# Top-5 closest-to-threshold converters and non-converters from the CV set.

# %%
top_conv  = baseline_df[baseline_df['TrueLabel']==1].sort_values('AbsMargin').head(5)
top_mci   = baseline_df[baseline_df['TrueLabel']==0].sort_values('AbsMargin').head(5)
print('Top-5 converters (smallest margin):'); print(top_conv.to_string(index=False))
print('\nTop-5 stable MCI (smallest margin):'); print(top_mci.to_string(index=False))

pc_records = []
for group_name, group_df in [('converter', top_conv), ('stable_mci', top_mci)]:
    for _, row in group_df.iterrows():
        sample   = cv_dataset[int(row['DatasetIndex'])]
        true_lbl = int(row['TrueLabel'])
        pid      = str(row['PatientID'])
        for method in noise_methods:
            for nl in noise_levels:
                for trial in range(n_trials):
                    emb  = perturb_and_embed(sample, method, nl)
                    prob = best_clf.predict_proba(best_scaler.transform(emb[None]))[0,1]
                    pred = int(prob >= ACTIVE_THRESHOLD)
                    pc_records.append({
                        'Group': group_name, 'PatientID': pid,
                        'TrueLabel': true_lbl, 'Method': method,
                        'NoiseLevel': nl, 'Trial': trial,
                        'Probability': float(prob),
                        'CorrectPrediction': int(pred == true_lbl),
                    })

pc_df = pd.DataFrame(pc_records)
pc_summary = (
    pc_df.groupby(['Group','PatientID','Method','NoiseLevel'])['CorrectPrediction']
    .mean().reset_index().rename(columns={'CorrectPrediction':'StabilityRate'})
)

# Plot
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
grp_colors = {'converter': '#F44336', 'stable_mci': '#2196F3'}
for row_i, grp_name in enumerate(['converter', 'stable_mci']):
    grp_sub = pc_summary[pc_summary['Group'] == grp_name]
    for col_i, method in enumerate(['feature_noise', 'edge_perturbation']):
        ax = axes[row_i][col_i]
        msub = grp_sub[grp_sub['Method'] == method]
        for pid, pdata in msub.groupby('PatientID'):
            ax.plot(pdata['NoiseLevel']*100, pdata['StabilityRate'],
                    marker='o', alpha=0.7, color=grp_colors[grp_name], lw=1.5)
        ax.set_title(f'{grp_name}  |  {method.replace("_"," ").title()}')
        ax.set_xlabel('Noise (%)'); ax.set_ylabel('Stability')
        ax.set_ylim(-0.05, 1.05); ax.grid(alpha=0.3)
fig.suptitle('Per-patient robustness (top-5 closest to threshold)', fontsize=12)
plt.tight_layout(); plt.show()
# Out:
# Top-5 converters (smallest margin):
#  DatasetIndex PatientID  TrueLabel  Probability  Predicted    AbsMargin
#           338 c81213449          1     0.193725          1 1.905264e-07
#           385 e7967bcd4          1     0.200609          1 6.883802e-03
#           264 a5cceacea          1     0.182849          0 1.087665e-02
#           349 cd3bf904f          1     0.175377          0 1.834856e-02
#           236 91383c1f8          1     0.165242          0 2.848292e-02
#
# Top-5 stable MCI (smallest margin):
#  DatasetIndex PatientID  TrueLabel  Probability  Predicted  AbsMargin
#           135 545f96b8d          0     0.200263          1   0.006538
#            75 383d33cde          0     0.182537          0   0.011188
#           204 7c86c18fc          0     0.209686          1   0.015960
#           370 df57b92f6          0     0.210081          1   0.016356
#           103 434050aec          0     0.170392          0   0.023333

# %% [markdown]
# ## UMAP coloured by prediction vs ground truth

# %%
try:
    import umap
    reducer = umap.UMAP(n_neighbors=15, min_dist=0.1,
                        random_state=RANDOM_STATE, metric='euclidean')
    emb_2d = reducer.fit_transform(cv_emb)

    cv_prob_all = best_clf.predict_proba(best_scaler.transform(cv_emb))[:, 1]
    cv_pred_all = (cv_prob_all >= ACTIVE_THRESHOLD).astype(int)
    correct     = (cv_pred_all == cv_labels).astype(int)

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    color_diag = ['#F44336' if l==1 else '#2196F3' for l in cv_labels]
    axes[0].scatter(emb_2d[:,0], emb_2d[:,1], c=color_diag, alpha=0.7, s=25,
                    edgecolors='k', linewidths=0.2)
    axes[0].set_title('Ground truth  (red=converter, blue=mci)')

    color_pred = ['#F44336' if p==1 else '#2196F3' for p in cv_pred_all]
    axes[1].scatter(emb_2d[:,0], emb_2d[:,1], c=color_pred, alpha=0.7, s=25,
                    edgecolors='k', linewidths=0.2)
    axes[1].set_title('Predicted label')

    color_corr = ['#4CAF50' if c==1 else '#FF9800' for c in correct]
    axes[2].scatter(emb_2d[:,0], emb_2d[:,1], c=color_corr, alpha=0.7, s=25,
                    edgecolors='k', linewidths=0.2)
    axes[2].set_title('Correct (green) vs Wrong (orange)')

    for ax in axes:
        ax.set_xlabel('UMAP 1'); ax.set_ylabel('UMAP 2'); ax.grid(alpha=0.3)
    fig.suptitle(f'UMAP of CV embeddings  |  GAAE: {GAAE_RUN_NAME}', fontsize=11)
    plt.tight_layout(); plt.show()
except ImportError:
    print('umap-learn not installed: pip install umap-learn')

# %% [markdown]
# ## Subject-level rollup (v2)
#
# The CV/test AUC reported above is **scan-level** — each subject contributes
# one row per scan. A subject with N scans is N× more influential than a
# single-visit subject. The cell below collapses scan-level predictions to
# one row per subject and re-computes AUC.

# %%
# v2 subject-level rollup — quote these numbers alongside the scan-level AUC.
from model.utils.metrics import aggregate_scan_to_subject
from sklearn.metrics import roc_auc_score

def report_subject_auc(probs, sids, labels, scan_order=None, name=''):
    for reduce in ('mean', 'max', 'last' if scan_order is not None else 'median'):
        try:
            _, p, y = aggregate_scan_to_subject(
                probs, sids, labels, reduce=reduce, scan_order=scan_order,
            )
        except ValueError as e:
            print(f'  [{name}] reduce={reduce}: {e}')
            continue
        auc = roc_auc_score(y, p) if len(set(y)) > 1 else float('nan')
        print(f'  [{name}] reduce={reduce:<6} n_subjects={len(y):<4} subject-AUC={auc:.4f}')

# Expects the notebook to have produced: probs, scan_subject_ids, labels.
# Adapt variable names per notebook if needed.
try:
    report_subject_auc(probs, scan_subject_ids, labels, name='test')
except NameError:
    print('Set probs / scan_subject_ids / labels (scan-level arrays) before running this cell.')
